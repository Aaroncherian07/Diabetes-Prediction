# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0            6      148             72             35        0  33.6  \
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin
# count   768.000000  768.000000     768.000000     768.000000  768.000000  \
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# Visualizing missing data
import missingno as msno
msno.matrix(df)
plt.xlabel('Missing Value Matrix')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Exploratory Data Analysis

# %%
plt.figure(figsize=(12,7))
sns.histplot(df['Pregnancies'], facecolor ='c', bins=100, stat='density')
plt.xlabel('Pregnancies')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %%
plt.figure(figsize=(12,7))
sns.histplot(df['Glucose'], facecolor ='r', bins=100, stat='density')
plt.xlabel('Glucose')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %%
plt.figure(figsize=(12,7))
sns.histplot(df['BloodPressure'], facecolor ='b', bins=100, stat='density')
plt.xlabel('BloodPressure')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %%
plt.figure(figsize=(12,7))
sns.histplot(df['SkinThickness'], facecolor='g', bins=100, stat='density')
plt.xlabel=('SkinThickness')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# # Visulizing the Target Variable

# %%
import matplotlib.style as style
style.available

style.use('seaborn-pastel')
labels =['Healthy', 'Diabetic']
df['Outcome'].value_counts().plot(kind='pie', labels=labels, subplots=True, autopct='%1.0f%%', labeldistance=1.2, figsize=(9,9))
# Out:
# array([<Axes: ylabel='count'>], dtype=object)

# %%
from matplotlib.pyplot import figure, show

figure(figsize=(8,6))
ax = sns.countplot(data=df, x=df['Outcome'], palette='husl')
ax.set_xticklabels(['Healthy', 'Diabetic'])
healthy, diabetes = df['Outcome'].value_counts().values
print('Sample of diabetic people:', diabetes)
print('Sample of healthy people:', healthy)
# Out:
# Sample of diabetic people: 268
# Sample of healthy people: 500

# %% [markdown]
# # Distribution of other features w.r.t Outcome

# %%
plt.figure()
ax = sns.histplot(df['Pregnancies'][df.Outcome==1], color="darkturquoise", kde=True, stat='density', linewidth=0)
sns.histplot(df['Pregnancies'][df.Outcome==0], color="lightcoral", kde=True, stat='density', linewidth=0)
plt.legend(['Diabetes', 'No Diabetes'])

# %%
plt.figure()
ax = sns.histplot(df['DiabetesPedigreeFunction'][df.Outcome==1], color="darkturquoise", kde=True, stat='density', linewidth=0)
sns.histplot(df['DiabetesPedigreeFunction'][df.Outcome==0], color="lightcoral", kde=True, stat='density', linewidth=0 )
plt.legend(['Diabetes', 'No Diabetes'])

# %%
plt.figure()
ax = sns.histplot(df['Glucose'][df.Outcome==1], color="darkturquoise", kde=True, stat='density', linewidth=0)
sns.histplot(df['Glucose'][df.Outcome==0], color="lightcoral", kde=True, stat='density', linewidth=0 )
plt.legend(['Diabetes', 'No Diabetes'])

# %%
sns.pairplot(df, hue='Outcome', palette='Reds')

# %% [markdown]
# # Finding Corelation between Columns

# %%
matrix = df.corr()
f, ax = plt.subplots(figsize=(12,7))
sns.heatmap(matrix, vmax=7, square=True, cmap='YlGnBu', annot=True, linewidth=5).set_title('Corelation Heatmap')
# Out:
# Text(0.5, 1.0, 'Corelation Heatmap')

# %% [markdown]
# # Spliting the data to training and testing data

# %%
from sklearn.model_selection import train_test_split
X= df.iloc[:, :-1]
y= df.iloc[:, -1]

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0            6      148             72             35        0  33.6  \
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.3, random_state=42)

# %% [markdown]
# # Checking for values which are 0

# %%
print('Total number of rows in the dataset:', len(df))
print('Total number of rows in the Glucose which are zero:', len(df.loc[df['Glucose']==0]))
print('Total number of rows in the Blood Pressure which are zero:', len(df.loc[df['BloodPressure']==0]))
print('Total number of rows in the Skin Thickness which are zero:', len(df.loc[df['SkinThickness']==0]))
print('Total number of rows in the Insulin which are zero:', len(df.loc[df['Insulin']==0]))
print('Total number of rows in the BMI which are zero:', len(df.loc[df['BMI']==0]))
print('Total number of rows in the Diabetes Pedigree Function which are zero:', len(df.loc[df['DiabetesPedigreeFunction']==0]))
print('Total number of rows in the Age which are zero:', len(df.loc[df['Age']==0]))
# Out:
# Total number of rows in the dataset: 768
# Total number of rows in the Glucose which are zero: 5
# Total number of rows in the Blood Pressure which are zero: 35
# Total number of rows in the Skin Thickness which are zero: 227
# Total number of rows in the Insulin which are zero: 374
# Total number of rows in the BMI which are zero: 11
# Total number of rows in the Diabetes Pedigree Function which are zero: 0
# Total number of rows in the Age which are zero: 0

# %%
from sklearn.impute import SimpleImputer
fill=SimpleImputer(missing_values=0, strategy='mean')
X_train= fill.fit_transform(X_train)
X_test= fill.fit_transform(X_test)

# %% [markdown]
# # Metrics

# %%
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, classification_report, precision_score, recall_score
from sklearn.metrics import confusion_matrix, precision_recall_curve, roc_curve, auc, log_loss

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver='lbfgs', class_weight='balanced', max_iter=1000, random_state=42)
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)
lrscore = lr.score(X_test, y_test)

# %%
y_pred_proba = lr.predict_proba(X_test)[:, 1]
[fpr1, tpr1, thr1] = roc_curve(y_test, y_pred_proba)

print('Train/Test split results:\n')
print(lr.__class__.__name__+" basic accuracy is %2.3f" % accuracy_score(y_test, y_pred_lr))
print(lr.__class__.__name__+" log loss is %2.3f" % log_loss(y_test, y_pred_lr))
print(lr.__class__.__name__+" auc is %2.3f" % auc(fpr1, tpr1))
# Out:
# Train/Test split results:
#
# LogisticRegression basic accuracy is 0.740
# LogisticRegression log loss is 9.379
# LogisticRegression auc is 0.836

# %% [markdown]
# # SVM Classfier

# %%
from sklearn.svm import SVC

svc_model = SVC(random_state=42)
svc_model.fit(X_train, y_train)
y_pred = svc_model.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[319,  30],
#        [ 98,  91]], dtype=int64)

# %%
print('Train/Test split result:\n')
print(svc_model.__class__.__name__+" basic accuracy is %2.3f" % accuracy_score(y_test, y_pred))
# Out:
# Train/Test split result:
#
# SVC basic accuracy is 0.762

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

# %%
print(rf.__class__.__name__+" basic accuracy is %2.3f"% accuracy_score(y_test, y_pred))
# Out:
# RandomForestClassifier basic accuracy is 0.753

# %% [markdown]
# # KNN Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=23)
knn.fit(X_train, y_train)

print(knn.score(X_test, y_test))
print("Accuracy = {}".format(round(knn.score(X_test, y_test),2) * 100)+"%")
# Out:
# 0.7360594795539034
# Accuracy = 74.0%

# %%
neighbors = np.arange(1,9)
train_accuracy = np.empty(len(neighbors))
test_accuracy = np.empty(len(neighbors))

# %%
for i, k in enumerate(neighbors):
    
    knn = KNeighborsClassifier(n_neighbors=k)
    
    knn.fit(X_train, y_train)
    
    train_accuracy[i] = knn.score(X_train, y_train)
    
    test_accuracy[i] = knn.score(X_test, y_test)

# %%
_ = plt.title('KNN varying number of neighbors')
_ = plt.plot(neighbors, test_accuracy, label='Testing Accuracy')
_ = plt.plot(neighbors, train_accuracy, label='Training Accuracy' )
plt.legend()
#plt.xlabel('No of neighbors')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# # XGBoost Classifier

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import make_scorer
from pandas import MultiIndex, Int16Dtype


param_test = {
    'n_estimators': [10, 50, 100],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1,3],
    'gamma':[i/10.0 for i in range(0,5)],
    'subsample':[0.5,0.75,1],
    'colsample_bytree': [0.5,0.75,1],
    'learning_rate':[0.01,0.05,1]
}

scoring = {'AUC': 'roc_auc', 'Accuracy': make_scorer(accuracy_score)}

xgb = GridSearchCV(estimator = XGBClassifier(eval_metric='mlogloss', use_label_encoder=False),
                               param_grid=param_test,
                               scoring=scoring,
                               cv=5,
                               verbose=1,
                               refit='Accuracy',
                               n_jobs=-1)

xgb.fit(X_train, y_train)
y_pred = xgb.predict(X_test)
# Out:
# Fitting 5 folds for each of 2430 candidates, totalling 12150 fits

# %%
print(xgb.__class__.__name__+" basic accuracy is %2.3f"% accuracy_score(y_test, y_pred))
# Out:
# GridSearchCV basic accuracy is 0.719

# %% [markdown]
# # Algorithm Analysis

# %%
from sklearn import ensemble, linear_model, neighbors, svm, tree
from sklearn import svm, model_selection, tree, linear_model, neighbors, ensemble

Model = [lr, svc_model, rf, xgb, knn]

# %%
Model_columns = []
Model_compare = pd.DataFrame(columns = Model_columns)

row_index=0
for alg in Model:
    predicted=alg.fit(X_train, y_train).predict(X_test)
    fp, tp, th = roc_curve(y_test, predicted)
    Model_name=alg.__class__.__name__
    Model_compare.loc[row_index, 'Model name'] =  Model_name
    Model_compare.loc[row_index, 'Model Test Accuracy'] = round(alg.score(X_test, y_test),4)
    Model_compare.loc[row_index, 'Model Test Accuracy'] = round(alg.score(X_test, y_test),4)
    Model_compare.loc[row_index, 'Model Precision'] = precision_score(y_test, predicted)
    Model_compare.loc[row_index, 'Model Recall'] = recall_score(y_test, predicted)
    Model_compare.loc[row_index, 'Model AUC'] = auc(fp, tp)
    
    row_index=+1
    
Model_compare.sort_values(by=['Model Test Accuracy'], ascending=False, inplace=True)
Model_compare
# Out:
# Fitting 5 folds for each of 2430 candidates, totalling 12150 fits
#              Model name  Model Test Accuracy  Model Precision  Model Recall
# 0    LogisticRegression               0.7398         0.606987      0.735450  \
# 1  KNeighborsClassifier               0.7175         0.658120      0.407407
#
#    Model AUC
# 0   0.738785
# 1   0.646397
